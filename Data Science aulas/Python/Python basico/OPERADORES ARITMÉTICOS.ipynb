# %% [markdown]
# # 3 - Operadores Aritméticos

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Faça os testes na célula abaixo:

# %%
# Faça seus testes aqui:
x = 7
y = 4

def numeros():
  if x > y:
    print(f'{x} + {y} = {x+y}')
  else:
    print(f'{x} - {y} = {x-y}')

numeros()

# %%
# Saída Formatada: Usando print(f" ......")

# %%
# Saída Formatada: Usando print(f" ......")

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Faça testes
z = 6
print(f'{(y+x)*z}')
# Out:
# 66

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Faça testes!
print(f'{x**y}')
print(f'{x**0.8}')
# Out:
# 2401
# 4.743276393803367

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### Exercício:

# %% [markdown]
#  Supondo que A, B e C são variáveis de tipo inteiro, com valores iguais a 5, 10 e –8, respectivamente, uma variável real D, com valor de 1.5, resolva passo a passo (obedecendo a ordem de prioridade) as expressões aritméticas abaixo e determine quais são os resultados.
#
# a)	2 * A % 3 – C
#
# b)	( - 2 * C)**0.5  / 4
#
# c)	((20 // 3) // 3) + 2** 8 / 2
#
# d)	(30 % 4 * 3**3 ) * -1
#
# e)	(-C)**2 + ( D * 10 )/A
#
# f)	A ** (B/A) ** 0.5 + C * D

# %%
a = 5
b = 10
c = -8
d = 1.5

print(f'{2*a % 3 - c}')
print(f'{(2*c)**0.5 / 4}')
print(f'{((20//3) // 3) + 2**8 / 2}')
print(f'{(30%4*3**3)*-1}')
print(f'{(-c)**2 + (d*10)/a}')
print(f'{a**(b/a)**0.5+c*d}')
# Out:
# 9
# (6.123233995736766e-17+1j)
# 130.0
# -54
# 67.0
# -2.2614822576645786

# %% [markdown]
# # Exercícios de Programas Lineares

# %% [markdown]
# ## 1. Faça um programa que leia as 4 notas bimestrais de um aluno. Calcule e escreva a média aritmética obtida.

# %%
# Entrada de Dados: input
n_1 = 4
n_2 = 6
n_3 = 8
n_4 = 2
cal = (n_1+n_2+n_3+n_4)//4
# Processamento de Dados: 
def media ():
  if cal >= 5 :
    print(f'poxa sua media nao foi boa tem que ser maior que {n_2}')
    print(cal)
  # print(f'As notas do aluno nos bimestres foram {n_1},{n_2},{n_3} e {n_4}. A media da soma delas e {(n_1+n_2+n_3+n_4)/4}')
  else:
    print(f'parabens brother continue assim')
    print(cal)
# Saída de Dados:
media()
# Out:
# poxa sua media nao foi boa tem que ser maior que 6
# 5

# %% [markdown]
# ## 2. Faça um programa que leia os valores reais para largura, comprimento e altura de um paralelepípedo retângulo  e calcule o seu volume.

# %%
L = 6
C = 4
A = 3

print(f'volume do objeto e {L*C*A}')
# Out:
# volume do objeto 72

# %% [markdown]
# ## 3. Faça um programa que leia dois valores inteiros para as variáveis num1 e num2, em seguida efetue as operações de adição, subtração, multiplicação e divisão de num1 por num2, apresentando ao final os resultados obtidos.

# %%
num1 = L
num2 = C

print(f'{num1 + num2}')
print(f'{num1 - num2}')
print(f'{num1 * num2}')
print(f'{num1 // num2}')
# Out:
# 10
# 2
# 24
# 1

# %% [markdown]
# ## 4. Faça um programa que leia uma temperatura em graus Fahrenheit e apresentá-la convertida em graus Célsius. A fórmula de conversão é: C = (F – 32) * (5 / 9), onde F é a temperatura em Fahrenheit e C é a temperatura em Célsius.

# %%
F = 18
print(f'C ={(F-32)*(5/9)}')
# Out:
# C =-7.777777777777779

# %% [markdown]
# ## 5. Faça um programa que calcule e apresente o volume de uma lata de óleo, utilizando a fórmula: VOLUME = 3.14159 * R * R * ALTURA.

# %%
R = 6
print(f'{3.14159 * R * R * A}')
# Out:
# 339.29171999999994

# %% [markdown]
# ## 6. Faça um programa que leia dois valores para as variáveis num1 e  num2, efetuar a troca de valores de forma que a variável num1 passe a possuir o valor da variável num2 e que a variável num2 passe a possuir o valor da variável num1. Imprimir na tela os valores de num1 e num2 antes e depois da troca.

# %%
g = 2
i = 5
y = g
h = i
print(f'g = {g} e i = {i} sao assim agora se transformaram em y = {y} e h = {i}')
# Out:
# g = 2 e i = 5 sao assim agora se transformaram em y = 2 e h = 5

# %% [markdown]
# ## 7. Faça um programa que efetue o cálculo do valor de uma prestação em atraso, utilizando a fórmula: PRESTACAO = VALOR + (VALOR * (TAXA/100) * TEMPO), onde a TAXA é um valor constante de 2 e o TEMPO é dado em dias.

# %%
from random import randint
TAXA = 2
TEMPO = randint(0,9)
VALOR = randint(0,9)

print(f'PRESTACAO = {VALOR + (VALOR * (TAXA/100) * TEMPO)}')
# Out:
# PRESTACAO = 4.16

# %% [markdown]
# ## 8. Faça um programa que receba o valor de um depósito e o valor da taxa de juros. Calcule e imprima o valor do rendimento e o valor total depois do rendimento.

# %%
d = int(input(f'deposite seu dinheiro aqui ! '))
tj = TAXA
rend = d*(1+tj)**TEMPO
print(f'seu rendimento foi de {d - rend} e voce tem {rend}')
# Out:
# deposite seu dinheiro aqui ! 9
# seu rendimento foi de -72 e voce tem 81

# %% [markdown]
# ## 9. Faça um programa que receba um número inteiro positivo, calcule e imprima a tabuada de multiplicação desse número.

# %%
v = int(input(f'fala um numero :  '))

for x in range(0,11):
  print(v*x)
# Out:
# fala um numero :  6
# 0
# 6
# 12
# 18
# 24
# 30
# 36
# 42
# 48
# 54
# 60

# %% [markdown]
# ## 10. Faça um programa que receba o valor do salário de um funcionário e o valor do salário mínimo. Calcule e imprima quantos salários mínimos ganha esse funcionário.

# %%
sal = int(input(f'qual eo seu salario: '))
sal_min = int(input(f'qual eo seu salario minimo da profissao: '))


def qant():
    if sal >= sal_min:
        print(f'voce ganha{sal//sal_min} salarios minimos')
    else:
        print('coloque seu real salario seu rico')


qant()
# Out:
# qual eo seu salario: 300
# qual eo seu salario minimo da profissao: 150
# 2

# %% [markdown]
# ## 11. Faça um programa que receba um número inteiro, calcule e imprima a raiz quadrada desse número e esse número elevado à quinta potência.

# %%
n = int(input(f'fala um numero: '))

print(f'{(n**2)*5}')
# Out:
# fala um numero: 12
# 720

# %% [markdown]
# ## 12. Faça um programa que receba um número real, calcule e imprima o valor referente ao volume do cubo que tenha este número real como lado.

# %%
num_real = 8

print(f'{num_real*3}')
# Out:
# 24
