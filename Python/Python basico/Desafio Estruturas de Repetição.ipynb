# %% [markdown]
# **NOME:**

# %% [markdown]
# CRIAR / COMPARTILHAR AQUI UM LINK PARA SEU PRÓPRIO NOTEBOOK COLAB: [Clique Aqui!](https://)

# %% [markdown]
# # O que vamos Praticar:
# <br/>
# longmapsto$ <b>ESTRUTURAS DE CONTROLE - REPETIÇÃO: </b><b> FOR / IN RANGE / WHILE / BREAK </b>.<br/><br/>

# %% [markdown]
# ## Fazer dois (2) exercícios de Repetição da lista usando o comando **FOR + IN RANGE** (a sua escolha);

# %% [markdown]
# 1) Escrever um algoritmo para exibir os múltiplos de 3 compreendidos no intervalo: [3 100].

# %%
print("Os multiplos de 3 sao : ")
for m in range (3,100):
  if m % 3 == 0:
    print(f'numero: {m}')

# %% [markdown]
# 2) Escrever um algoritmo para exibir os múltiplos de 11, a soma e a média dos múltiplos de 11, em ordem
# decrescente (inversa), compreendidos entre o intervalo: [200 100].

# %%
s = 0
for c in range(200,100,-1): 
  if c % 11 == 0:
    s+=c
    print(f"{c}")
print(f"soma {s}")
print(f"media {s/2}")

# %% [markdown]
# ## Fazer dois (2) exercícios de Repetição da lista usando o comando **WHILE** (a sua escolha):

# %% [markdown]
# 3) Escrever um algoritmo em Python para exibir os múltiplos de ƞ compreendidos entre o intervalo:
# [𝐿𝑖𝑚𝑖𝑡𝑒𝐼𝑛𝑓𝑒𝑟𝑖𝑜𝑟 𝐿𝑖𝑚𝑖𝑡𝑒𝑆𝑢𝑝𝑒𝑟𝑖𝑜𝑟] ϵ ℕ. Sendo que:
# ✓ {ƞ ∈ ℕ/ ƞ ≥ 2}
# ✓ {𝐿𝑖𝑚𝑖𝑡𝑒𝐼𝑛𝑓𝑒𝑟𝑖𝑜𝑟 , 𝐿𝑖𝑚𝑖𝑡𝑒𝑆𝑢𝑝𝑒𝑟𝑖𝑜𝑟 ∈ ℕ/ 𝐿𝑖𝑚𝑖𝑡𝑒𝑆𝑢𝑝𝑒𝑟𝑖𝑜𝑟 ≥ 𝐿𝑖𝑚𝑖𝑡𝑒𝐼𝑛𝑓𝑒𝑟𝑖𝑜𝑟}

# %%
n = int(input("numero "))

if n >= 2:
  while n <= 100 and n % n == 0:
    n+=n
    print(n)

# %% [markdown]
# 4) Faça um algoritmo que exiba a soma dos PARES e ÍMPARES compreendidos entre [10 99]

# %%
a = 10
p = 0
i = 0
while a < 99:
  a+=1
  if a % 2 == 0:
    p+=a
  else:
    i+=a
print(f"impares {i}")
print(f"pares {p}")

# %% [markdown]
# ## Fazer dois (2) exercícios de Repetição da lista usando o comando **WHILE + BREAK** (a sua escolha):

# %% [markdown]
# 5) Escreva um algoritmo que leia de 10.000 habitantes de uma pequena cidade se está empregado ou não e
# exiba em porcentagem a quantidade de empregados e desempregados desta pequena cidade.

# %%
hab = 0
e = 0
d = 0
while hab < 10000:
  print('vc esta empregado?')
  print('[1] para Sim')
  print('[2] para Não')
  print('[0] para acabar pesquisa')
  opcao = int(input(f'resposta '))
  if hab == 10000:
    print('obrigado por responder o questionario')
    break
  elif opcao == 0:
    print('obrigado por responder o questionario')
    break
  elif opcao == 1:
    e += 1
  else:
    d += 1
  empregados = e / (e + d) * 100
  desempregados = d / (e + d) * 100
  print(f'empregados: {empregados}%.')  
  print(f'desempregados: {desempregados}%.')
  hab += 1

# %% [markdown]
# 6) Escreva um algoritmo que leia o salário em reais (R$) de 1000 clientes de um shopping e exiba na tela,
# em porcentagem, a divisão dos clientes por tipo: A, B ou C, conforme a seguir:
# ✓ A: Maior ou igual a 15 Salários Mínimos ou
# ✓ B: Menor que 15 Salários Mínimos ou maior ou igual a 5 Salários Mínimos ou
# ✓ C: Menor que 5 Salários Mínimos.
# Declarar o Salário Mínimo (SM: Pesquisar no Google)

# %%
clientes = 0
a = 0
b = 0
c = 0
while clientes < 1000:
  salario = int(input(f'quanto vc ganha em reais ? '))
  print("coloque [0] para sair do programa")
  ############
  if salario == 0:
    print('obrigado por responder o questionario')
    break
  elif salario >= 16500:
    a+=1
  elif salario == 16500 or salario >= 5500:
    b+=1
  else:
    c+=1
  maior = a / (a + b + c )*100
  medio = b / (a + b + c )*100
  minimo = c / (a + b + c )*100
  print(f'Maior ou igual a 15 Salários Mínimos                                  {maior}%.')  
  print(f'Menor que 15 Salários Mínimos ou maior ou igual a 5 Salários Mínimos: {medio}%.')
  print(f'menor que 5 salarios:                                                {minimo}%.')
  clientes += 1

# %% [markdown]
# # DESAFIO: Senha da porta mágica

# %% [markdown]
# DESCRIÇÃO DO JOGO:

# %% [markdown]
# <center>
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Descobrir a senha da porta mágica. Com isso:
#
# $\longmapsto$ **REGRA 1**: O Guerreiro tem **7 chances antes da mort**e;
#
# $\longmapsto$ **REGRA 2**: O Oráculo diz uma **DICA**; se o número escolhido pelo guerreiro é:
#
# *   MAIOR que o Segredo da porta ou
# *   MENOR que o Segredo da porta.

# %%
import numpy as np

# %%
# ESQUELETO DO PROGRAMA:
while True:
  print("MENU: ")
  print("Escolha: [1] para jogar ou [0] para sair: ")
  resposta = int(input())
  if (resposta == 0):
    print("Fim do Jogo.")
    break
  elif (resposta != 1):
    print("Erro. Escolha de novo")
  else:
    segredo = np.random.randint(1, 101, 1)
    print(f"Segredo: {segredo[0]}")
    
    # FAZER O JOGO AQUI!  # No máximo 7 chances antes da morte!
  tentativas = 0 
  while True:    
    respostag = int(input('adivinhe um numero que esteja entre 0 e 100 ? '))
    tentativas+=1        
    while respostag != segredo[0] or respostag == segredo[0]:
      if tentativas < 8 and respostag < segredo[0]:
        print(f'tente novamente o numero que procura e MAIOR que esse NUMERO {respostag} vc tem {tentativas} ')
        break
      elif tentativas < 8 and respostag > segredo[0]:
        print(f'tente novamente o numero que procura e MENOR que esse NUMERO {respostag} vc tem {tentativas}')
        break
      elif respostag == segredo[0]:
        print(f'voce acertou o numero e {segredo[0]}')
        break
      else:
        print(f'voce morreu')
        break
