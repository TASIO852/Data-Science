# %%
import pandas as pd

# %%
df = pd.read_csv('C:/Users/tarsi/OneDrive/Documentos/Data Science/Data-Science/Python/Data/melb_data.csv')
df.head()
# Out:
#    Unnamed: 0      Suburb           Address  Rooms Type      Price Method  \
# 0           1  Abbotsford      85 Turner St      2    h  1480000.0      S
# 1           2  Abbotsford   25 Bloomburg St      2    h  1035000.0      S
# 2           4  Abbotsford      5 Charles St      3    h  1465000.0     SP
# 3           5  Abbotsford  40 Federation La      3    h   850000.0     PI
# 4           6  Abbotsford       55a Park St      4    h  1600000.0     VB
#
#   SellerG       Date  Distance  ...  Bathroom  Car  Landsize  BuildingArea  \
# 0  Biggin  3/12/2016       2.5  ...       1.0  1.0     202.0           NaN
# 1  Biggin  4/02/2016       2.5  ...       1.0  0.0     156.0          79.0
# 2  Biggin  4/03/2017       2.5  ...       2.0  0.0     134.0         150.0
# 3  Biggin  4/03/2017       2.5  ...       2.0  1.0      94.0           NaN
# 4  Nelson  4/06/2016       2.5  ...       1.0  2.0     120.0         142.0
#
# ...

# %%
df_2 = df.select_dtypes(exclude='object')

# %%
df_2.head()
# Out:
#    Unnamed: 0  Rooms      Price  Distance  Postcode  Bedroom2  Bathroom  Car  \
# 0           1      2  1480000.0       2.5    3067.0       2.0       1.0  1.0
# 1           2      2  1035000.0       2.5    3067.0       2.0       1.0  0.0
# 2           4      3  1465000.0       2.5    3067.0       3.0       2.0  0.0
# 3           5      3   850000.0       2.5    3067.0       3.0       2.0  1.0
# 4           6      4  1600000.0       2.5    3067.0       3.0       1.0  2.0
#
#    Landsize  BuildingArea  YearBuilt  Lattitude  Longtitude  Propertycount
# 0     202.0           NaN        NaN   -37.7996    144.9984         4019.0
# 1     156.0          79.0     1900.0   -37.8079    144.9934         4019.0
# 2     134.0         150.0     1900.0   -37.8093    144.9944         4019.0
# 3      94.0           NaN        NaN   -37.7969    144.9969         4019.0
# 4     120.0         142.0     2014.0   -37.8072    144.9941         4019.0

# %%
df_2.corr()
# Out:
#                Unnamed: 0     Rooms     Price  Distance  Postcode  Bedroom2  \
# Unnamed: 0       1.000000  0.063194 -0.071270  0.267362  0.104123  0.103046
# Rooms            0.063194  1.000000  0.496430  0.286979  0.063034  0.948740
# Price           -0.071270  0.496430  1.000000 -0.169779  0.098790  0.474864
# Distance         0.267362  0.286979 -0.169779  1.000000  0.443318  0.294835
# Postcode         0.104123  0.063034  0.098790  0.443318  1.000000  0.064956
# Bedroom2         0.103046  0.948740  0.474864  0.294835  0.064956  1.000000
# Bathroom         0.042097  0.597444  0.463762  0.130633  0.114387  0.589968
# Car              0.090104  0.413361  0.237924  0.260462  0.056131  0.410400
# Landsize         0.026994  0.025640  0.037514  0.024945  0.024516  0.025607
# BuildingArea     0.014801  0.127357  0.094342  0.093891  0.051753  0.125580
# YearBuilt        0.135943 -0.060499 -0.324032  0.250276  0.044442 -0.048461
# ...

# %%
# Utilizando o próprio Pandas
df_2.corr().style.background_gradient(cmap='Blues')
# Out:
# <style type="text/css">
# #T_c43d4_row0_col0, #T_c43d4_row1_col1, #T_c43d4_row2_col2, #T_c43d4_row3_col3, #T_c43d4_row4_col4, #T_c43d4_row5_col5, #T_c43d4_row6_col6, #T_c43d4_row7_col7, #T_c43d4_row8_col8, #T_c43d4_row9_col9, #T_c43d4_row10_col10, #T_c43d4_row11_col11, #T_c43d4_row12_col12, #T_c43d4_row13_col13 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_c43d4_row0_col1, #T_c43d4_row4_col1 {
#   background-color: #dbe9f6;
#   color: #000000;
# }
# #T_c43d4_row0_col2, #T_c43d4_row9_col5 {
#   background-color: #d2e3f3;
#   color: #000000;
# }
# #T_c43d4_row0_col3 {
#   background-color: #9fcae1;
#   color: #000000;
# }
# #T_c43d4_row0_col4 {
#   background-color: #a5cde3;
#   color: #000000;
# }
# #T_c43d4_row0_col5, #T_c43d4_row4_col6, #T_c43d4_row9_col6, #T_c43d4_row12_col1, #T_c43d4_row12_col6 {
#   background-color: #d6e5f4;
#   color: #000000;
# }
# #T_c43d4_row0_col6, #T_c43d4_row8_col5 {
#   background-color: #e3eef9;
#   color: #000000;
# }
# ...

# %%
import seaborn as sns

# %%
sns.heatmap(df_2.corr())
# Out:
# <Axes: >

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize=(12, 8))

_ = sns.heatmap(df_2.corr(), cmap = 'Blues', linewidth = 0.5, annot = True)
